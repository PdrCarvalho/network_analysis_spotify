# %% [markdown]
# ## Libs Imports

# %%
import random

# %%
import pandas as pd 
import json 
import networkx as nx
from itertools import combinations
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches

# %% [markdown]
# ## Created Sample

# %%
# f = open('spotfy_playlists.json')
# js = f.read()
# f.close()
# data_playlist = json.loads(js)['playlists']
# sample = random.sample(data_playlist,30)
# with open('data_spotfy.json', 'w') as f:
#     json.dump(test_sample2, f)

# %% [markdown]
# ##Import data and create Graph

# %%
f = open('/content/data_spotfy.json')
js = f.read()
f.close()
sample = json.loads(js)

# %%
graph = nx.Graph()
# test_sample = random.sample(data_playlist,40)
for playlist in sample:
  subgraph = set()
  for music in playlist['tracks']:
    graph.add_node(music['artist_name'])
    subgraph.add(music['artist_name'])

  for node_orig, node_target in combinations(list(subgraph),2):
    if graph.has_edge(node_orig, node_target):
      graph[node_orig][node_target]['weight'] += 1

    else:
      graph.add_edge(node_orig, node_target, weight=1,playlist_ids=playlist['pid'])
biggest_componet  = None
for component in nx.connected_components(graph):
    print(len(component))
    if biggest_componet is None:
      biggest_componet = list(component)
    elif len(biggest_componet) < len(component):
      biggest_componet = list(component)
graph = graph.subgraph(biggest_componet)
# Out:
# 417
# 7
# 4
# 7
# 6

# %%
graph.number_of_nodes()
# Out:
# 417

# %%
graph.number_of_edges()
# Out:
# 11703

# %%
# nx.write_graphml(graph,'spotify_graph.graphml')

# %% [markdown]
# ## Global metrics

# %% [markdown]
# ### Eccentricity, Diameter, Periphery, Radius and Center.

# %%
nx.eccentricity(graph)
# Out:
# {'Dolly Parton': 4,
#  'Tina Turner': 4,
#  'Bonnie Tyler': 4,
#  'Alanis Morissette': 4,
#  'Dido': 4,
#  'Alannah Myles': 4,
#  'Carly Simon': 4,
#  'Cher': 4,
#  'Big Brother & The Holding Company': 4,
#  'Blondie': 4,
#  'Stevie Nicks': 4,
#  'The Cranberries': 4,
#  'Heart': 4,
#  'Jefferson Airplane': 4,
#  'Joan Jett': 4,
#  'Pat Benatar': 4,
#  'Fleetwood Mac': 4,
#  "'Til Tuesday": 4,
#  'Pretenders': 4,
#  'Fiona Apple': 4,
#  'Bonnie Raitt': 4,
#  'Florence + The Machine': 4,
#  'No Doubt': 4,
#  'Tracy Chapman': 4,
#  '10,000 Maniacs': 4,
#  'Aretha Franklin': 4,
#  'Whitney Houston': 4,
#  'The Bangles': 4,
#  'Natalie Imbruglia': 4,
#  'The Pointer Sisters': 4,
#  'Toni Basil': 4,
#  'Irene Cara': 4,
#  'Bananarama': 4,
#  'The Weather Girls': 4,
#  'Berlin': 4,
#  'Gloria Gaynor': 4,
#  'Janis Joplin': 4,
#  'Belinda Carlisle': 4,
#  'Kiesza': 4,
#  'Garbage': 4,
#  'The Supremes': 4,
#  'Madonna': 4,
#  "Sinéad O'Connor": 4,
#  'Shelly West': 4,
#  'Lorde': 4,
#  'Sara Bareilles': 4,
#  'Chris Janson': 4,
#  'Brooks & Dunn': 4,
#  'Aerosmith': 4,
#  'AWOLNATION': 4,
#  'Lonestar': 4,
#  'Kansas': 4,
#  'Quiet Riot': 4,
#  'Lil Wayne': 3,
#  'Eminem': 3,
#  'Uncle Kracker': 4,
#  'Little Big Town': 4,
#  'Nitty Gritty Dirt Band': 4,
#  'Luke Bryan': 4,
#  'Jason Derulo': 3,
#  'Josh Turner': 4,
#  'Ed Sheeran': 4,
#  'Tim McGraw': 4,
#  'Faith Hill': 4,
#  'John Legend': 4,
#  'Leona Lewis': 4,
#  'Adele': 3,
#  'Kid Cudi': 3,
#  'Hollywood Undead': 4,
#  'Paramore': 4,
#  'Mariah Carey': 4,
#  'José Feliciano': 4,
#  'Andy Williams': 4,
#  'Phil Spector': 4,
#  'Daryl Hall & John Oates': 4,
#  'Idina Menzel': 4,
#  'Colin & Caroline': 4,
#  'Pentatonix': 4,
#  'Justin Bieber': 4,
#  'Diana Krall': 4,
#  'Kristen Bell': 4,
#  'Demi Lovato': 4,
#  'Tony Bennett': 4,
#  'Boston Pops Orchestra': 4,
#  'The Wanted': 4,
#  'Maroon 5': 4,
#  'The Monkees': 4,
#  'Ben E. King': 4,
#  'ABBA': 4,
#  'Bee Gees': 4,
#  'Bill Withers': 4,
#  'The Jackson 5': 4,
#  'Queen': 4,
#  'AC/DC': 4,
#  'Stealers Wheel': 4,
#  'Lynyrd Skynyrd': 4,
#  'Journey': 4,
#  'a-ha': 4,
#  'The Romantics': 4,
#  'Survivor': 4,
#  'Toto': 4,
#  'Wham!': 4,
#  'Simple Minds': 4,
#  'Rick Astley': 4,
#  'Culture Club': 4,
#  'Stevie Wonder': 4,
#  'Eagles': 4,
#  'Creedence Clearwater Revival': 4,
#  'Neil Diamond': 4,
#  'U2': 4,
#  'The Proclaimers': 4,
#  'Jack Johnson': 4,
#  'Spice Girls': 3,
#  'Bon Iver': 4,
#  'Bryan Adams': 4,
#  'The Beatles': 4,
#  'The Charlie Daniels Band': 4,
#  'Soulxpress': 4,
#  'Beyoncé': 4,
#  'Cassie': 4,
#  'The Pussycat Dolls': 4,
#  'Kelis': 4,
#  'Marina and the Diamonds': 4,
#  'Ashley Tisdale': 4,
#  'Nelly Furtado': 4,
#  'Khia': 4,
#  'Lil Mama': 4,
#  'Britney Spears': 4,
#  'Rihanna': 4,
#  'Fergie': 4,
#  'Busta Rhymes': 4,
#  "Destiny's Child": 4,
#  '50 Cent': 4,
#  'Selena Gomez': 4,
#  'Kreayshawn': 4,
#  'Nicki Minaj': 4,
#  'Shakira': 4,
#  'The Black Eyed Peas': 4,
#  'cupcakKe': 4,
#  'Blake Shelton': 4,
#  'Chris Young': 5,
#  'Highway Bros': 5,
#  'Easton Corbin': 5,
#  'Jason Aldean': 5,
#  'Toby Keith': 5,
#  'Billy Currington': 5,
#  'Rodney Atkins': 5,
#  'Kid Rock': 5,
#  'Caye': 6,
#  'Berhana': 6,
#  'Marc E. Bassy': 6,
#  'Daniel Caesar': 5,
#  'Abhi//Dijon': 6,
#  'Tontario': 6,
#  'Masego': 6,
#  'Jason Mraz': 4,
#  'The Audition': 4,
#  'Death Cab for Cutie': 4,
#  'La Dispute': 4,
#  'Of Mice & Men': 4,
#  'The Neighbourhood': 4,
#  'Owl City': 4,
#  'Zedd': 4,
#  'Teen Hearts': 4,
#  'This Wild Life': 4,
#  'Twenty One Pilots': 4,
#  'A Day To Remember': 4,
#  'Shania Twain': 4,
#  'Jhene Aiko': 4,
#  'Lana Del Rey': 5,
#  'Radiation City': 4,
#  'Private Island': 4,
#  'Circa Waves': 4,
#  'Dan Auerbach': 4,
#  'Fossil Collective': 4,
#  'Frightened Rabbit': 4,
#  'WATERS': 4,
#  'Dylan Kelly': 4,
#  'Boardwalk': 4,
#  'Broken Back': 4,
#  'Noirre': 4,
#  'Grouplove': 4,
#  'Rainbow Kitten Surprise': 4,
#  'Declan McKenna': 4,
#  'Generationals': 4,
#  'Westward the Tide': 4,
#  'The Tallest Man On Earth': 4,
#  'Ben Howard': 4,
#  'Life in Film': 4,
#  'JR JR': 4,
#  'Vacationer': 4,
#  'Gungor': 4,
#  'The Postelles': 4,
#  'Mutual Benefit': 4,
#  'Tigers in the Sky': 4,
#  'Waterstrider': 4,
#  'KONGOS': 4,
#  'Tall Heights': 4,
#  'Saint Motel': 4,
#  'Aaron Embry': 4,
#  'Black Taxi': 4,
#  'CHAPPO': 4,
#  'Rayland Baxter': 4,
#  'Langhorne Slim': 4,
#  'Lucius': 4,
#  'Kopecky': 4,
#  'Vance Joy': 4,
#  'Hippo Campus': 4,
#  'The Black Keys': 4,
#  'The Districts': 4,
#  'Moon Taxi': 4,
#  'Ezra Vine': 4,
#  'Andrew McMahon in the Wilderness': 4,
#  'Gregory Alan Isakov': 4,
#  'Dr. Dog': 4,
#  'Mighty Oaks': 4,
#  'The Irrepressibles': 4,
#  'Saint Raymond': 4,
#  "You Won't": 4,
#  'The Growlers': 4,
#  'The Shins': 4,
#  'Buxton': 4,
#  'Middle Brother': 4,
#  'Peter Wolf Crier': 4,
#  'Paul Simon': 4,
#  'Ha Ha Tonka': 4,
#  'The Strumbellas': 3,
#  'Oh Wonder': 4,
#  'Rationale': 4,
#  'High Highs': 4,
#  'Passenger': 4,
#  'Radical Face': 4,
#  'The Equatics': 4,
#  'Swim Deep': 4,
#  'Satellite Stories': 4,
#  'Panama': 4,
#  'Wolf Gang': 4,
#  'Air Traffic Controller': 4,
#  'The Crookes': 4,
#  'Morningsiders': 4,
#  'Matt Pond PA': 4,
#  'Tim Whybrow': 4,
#  'Freelance Whales': 4,
#  'Galimatias': 4,
#  'Alina Baraz': 4,
#  'Florida Georgia Line': 5,
#  'Jon Pardi': 5,
#  'Rascal Flatts': 4,
#  'Love and Theft': 5,
#  'Kip Moore': 5,
#  'The Band Perry': 5,
#  'Carrie Underwood': 5,
#  'Lady Antebellum': 5,
#  'Brantley Gilbert': 5,
#  'Aaron Lewis': 5,
#  'Zac Brown Band': 5,
#  'Pitbull': 4,
#  'Lupe Fiasco': 4,
#  'Albatraoz': 4,
#  'Bastille': 4,
#  'Slaptop': 4,
#  'Jessie J': 4,
#  'Jennifer Lopez': 4,
#  'Finatticz': 4,
#  'The Chainsmokers': 3,
#  'Casely': 4,
#  'Enrique Iglesias': 4,
#  'Flo Rida': 4,
#  'Redfoo': 4,
#  'Ester Dean': 4,
#  'Kat Deluna': 4,
#  'Major Lazer': 4,
#  'Sia': 4,
#  'Luis Fonsi': 4,
#  'Top Cats': 4,
#  'Lil Jon & The East Side Boyz': 4,
#  'Bubba Sparxxx': 4,
#  'Soulja Boy': 4,
#  'Bruno Mars': 4,
#  'Dj Laz': 4,
#  'Mark Ronson': 3,
#  'Fifth Harmony': 4,
#  'Meghan Trainor': 4,
#  'T-Pain': 4,
#  'Ariana Grande': 4,
#  'Hammock': 4,
#  'Ólafur Arnalds': 4,
#  'Helios': 4,
#  'NazcarNation': 4,
#  'Thievery Corporation': 4,
#  'José González': 4,
#  'Edward Sharpe & The Magnetic Zeros': 4,
#  'Parra for Cuva': 4,
#  'Mr. Probz': 4,
#  'Sam Smith': 4,
#  'Duke Dumont': 4,
#  'RJD2': 4,
#  'Rudimental': 4,
#  'Clean Bandit': 3,
#  'Amber Run': 4,
#  'Daithí': 4,
#  'Mapei': 4,
#  'Flight Facilities': 4,
#  'Daughter': 4,
#  'Dr. Toast': 4,
#  'Jonathan Byrd': 4,
#  'Evenings': 4,
#  'Skillet': 4,
#  '3FOR3': 4,
#  'Hillsong Young & Free': 4,
#  'Hillsong United': 4,
#  'KB': 4,
#  'Elevation Worship': 4,
#  'Andy Mineo': 4,
#  'Trip Lee': 4,
#  'Lecrae': 4,
#  'Taylor Swift': 4,
#  'for KING & COUNTRY': 4,
#  'DJ Snake': 4,
#  'Jack Ü': 4,
#  'Micah Tyler': 4,
#  '7eventh Time Down': 4,
#  'Jordan Feliz': 4,
#  'Francesca Battistelli': 4,
#  'Danny Gokey': 4,
#  "Da' T.R.U.T.H.": 4,
#  'Tedashii': 4,
#  'Ashes Remain': 4,
#  'Capital Kings': 4,
#  'Group 1 Crew': 4,
#  'NEEDTOBREATHE': 4,
#  'J Boog': 4,
#  'tobyMac': 4,
#  'Drake': 4,
#  'Jeremy Camp': 4,
#  'Steven Malcolm': 4,
#  'Matty Mullins': 4,
#  'Steven Furtick': 4,
#  'GAWVI': 4,
#  'Tauren Wells': 4,
#  'Mosaic MSC': 4,
#  'Landry Cantrell': 4,
#  'Mallary Hope': 4,
#  'Fellowship Creative': 4,
#  'Planetshakers': 4,
#  'Britt Nicole': 4,
#  'Hannah Kerr': 4,
#  'Essential Worship': 4,
#  'Joshua Micah': 4,
#  '2 Chainz': 4,
#  'Reik': 4,
#  'DJ Khaled': 3,
#  'Civil Twilight': 5,
#  'Nirvana': 5,
#  'Slaughter': 5,
#  'Counting Crows': 5,
#  'The Goo Goo Dolls': 5,
#  'The Wallflowers': 5,
#  'Marcy Playground': 5,
#  'Eagle-Eye Cherry': 5,
#  'Lifehouse': 4,
#  'Dave Matthews Band': 5,
#  'Semisonic': 5,
#  'David Gray': 5,
#  'R.E.M.': 5,
#  'Tal Bachman': 5,
#  'Gin Blossoms': 5,
#  'Howie Day': 5,
#  'Deep Blue Something': 5,
#  'Train': 5,
#  'Live': 5,
#  'Nancy Sinatra': 4,
#  'Dusty Springfield': 4,
#  'The Doors': 4,
#  'The Shirelles': 4,
#  'The Mamas & The Papas': 4,
#  'Bob Dylan': 4,
#  'Led Zeppelin': 4,
#  'The Kinks': 4,
#  'The Rolling Stones': 4,
#  'Al Green': 4,
#  'Roy Orbison': 4,
#  'Bo Diddley': 4,
#  'Otis Redding': 4,
#  'The Isley Brothers': 4,
#  'Marvin Gaye': 3,
#  'Johnny Cash': 4,
#  'Charli XCX': 4,
#  'MAX': 4,
#  'Post Malone': 3,
#  'AJR': 4,
#  'Alessia Cara': 3,
#  'Mike Posner': 4,
#  'Mandy Moore': 4,
#  'Andreas Moss': 4,
#  'NF': 4,
#  'Lil Dicky': 4,
#  'Snow Patrol': 4,
#  'Coldplay': 4,
#  'Breaking Benjamin': 4,
#  'Disturbed': 4,
#  'Three Days Grace': 4,
#  'Seether': 4,
#  'In Fear And Faith': 4,
#  'Five Finger Death Punch': 4,
#  'Foo Fighters': 4,
#  'The Killers': 4,
#  'Good Charlotte': 4,
#  'Camila Cabello': 4,
#  'Russ': 3,
#  'Lost Kings': 4,
#  'Alex & Sierra': 4,
#  'Austin': 4,
#  'Austin Awake': 4,
#  'Kane Brown': 4,
#  "Olivia O'Brien": 4,
#  'SoMo': 4,
#  'Sik World': 4,
#  'Jasmine Thompson': 4,
#  'Bingx': 4,
#  'Gavin James': 4,
#  'Snakehips': 3,
#  'Noah Cyrus': 4,
#  'Alex Da Kid': 4,
#  "Rag'n'Bone Man": 4,
#  'Labrinth': 4,
#  'Little Mix': 4,
#  'Bebe Rexha': 4,
#  'Niall Horan': 4,
#  'MKTO': 3,
#  'Gotye': 4,
#  'Hunter Hayes': 4,
#  'Lauv': 4,
#  'Martin Garrix': 3,
#  'Sam Hunt': 3,
#  'Kacey Musgraves': 4,
#  'Leroy Sanchez': 4,
#  'blackbear': 4,
#  'Alan Walker': 4,
#  'Joel Adams': 4,
#  'Old Dominion': 3,
#  'James Arthur': 4,
#  'Imagine Dragons': 4,
#  'Brett Young': 4,
#  'Dylan Scott': 4,
#  'Nothing More': 4,
#  'Unlike Pluto': 4,
#  'Colbie Caillat': 4,
#  'Miley Cyrus': 3,
#  'Perfect Two': 4,
#  'Jonas Brothers': 3,
#  'Echosmith': 4,
#  'Murphy Elmore': 4,
#  'DRAM': 3,
#  'Maggie Lindemann': 4,
#  'Isla Vista Worship': 5,
#  'Kings Kaleidoscope': 5,
#  'Ascend The Hill': 5,
#  'Judah & the Lion': 5,
#  'Enter The Worship Circle': 5,
#  'Jenn Johnson': 5,
#  'Brian and Jenn Johnson': 5,
#  'Jonathan David Helser': 5,
#  'Nathan Partain': 5,
#  'Phil Wickham': 5,
#  'Josh Garrels': 5,
#  'Rivers & Robots': 5,
#  'Misty Edwards': 5,
#  'Kristene Dimarco': 5,
#  'Laura Hackett': 5,
#  'Hillsong Worship': 5,
#  'Kalley Heiligenthal': 5,
#  'Page CXVI': 5,
#  'John Mark McMillan': 5,
#  'Will Reagan': 5,
#  'Cageless Birds': 5,
#  'The Sing Team': 5,
#  'Sean Feucht': 5,
#  'The Ember Days': 5,
#  'Bryan McCleery': 5,
#  'Warr Acres': 5,
#  'Jordan & Kristin Rippy': 5,
#  'Enterline': 5,
#  'Citizens & Saints': 5,
#  'Beastie Boys': 4,
#  'Third Eye Blind': 4,
#  'The Offspring': 4,
#  "Guns N' Roses": 4,
#  'Chuck Berry': 4,
#  'Ritchie Valens': 4,
#  'Little Richard': 4,
#  'WALK THE MOON': 4,
#  'Macklemore': 4,
#  'Macklemore & Ryan Lewis': 4,
#  'OutKast': 4,
#  'Kanye West': 3,
#  'JAY Z': 4,
#  'Papa Roach': 4,
#  'Flight of the Conchords': 4,
#  "Jane's Addiction": 4,
#  'New Found Glory': 4,
#  'Lit': 4,
#  'Akon': 4,
#  '2Pac': 4,
#  'Will Smith': 4,
#  'The Black Crowes': 4,
#  'Rage Against The Machine': 4,
#  'Electric Six': 4,
#  'fun.': 4,
#  'Spin Doctors': 4,
#  'Portugal. The Man': 4,
#  'The Clash': 4,
#  'Curtis Mayfield': 4,
#  'The Blues Brothers': 4,
#  'Chaka Demus & Pliers': 5,
#  'Beenie Man': 5,
#  'Sean Paul': 4,
#  'Cham': 5,
#  'Bunji Garlin': 5,
#  'Gyptian': 5,
#  'Tony Matterhorn': 5,
#  'Mr. Vegas': 5,
#  'Cutty Ranks': 5,
#  'Serani': 5,
#  'Shabba Ranks': 5,
#  'Dirtsman': 5,
#  'Nadine Sutherland': 5,
#  'Vicious': 5,
#  'Super Cat': 5,
#  'Buju Banton': 5,
#  'T.O.K.': 5,
#  'Kranium': 5,
#  'Ricky Blaze': 5,
#  'Vybz Kartel': 5,
#  'Rupee': 5,
#  'DJ Dynamite': 5,
#  'Kevin Lyttle': 5,
#  'Konshens': 5,
#  'Mavado': 5,
#  'Aidonia': 5,
#  'Dexta Daps': 5,
#  'Shaggy': 4,
#  'Tanto Metro & Devonte': 5,
#  'Demarco': 5,
#  'Zoelah': 5,
#  'Peter Ram': 5,
#  'Machel Montano': 5,
#  'KES the Band': 5,
#  'Alison Hinds': 5,
#  'Olatunji': 5,
#  'Flavour': 5,
#  'Elephant Man': 5,
#  'Timaya': 5,
#  'Wayne Wonder': 5,
#  'Popcaan': 5,
#  'Terror Fabulous': 5,
#  'Charly Black': 5,
#  'Ayo Jay': 5,
#  'Squeeze': 5,
#  'Sean Kingston': 4,
#  'Mad Cobra': 5,
#  'Korede Bello': 5,
#  'Tory Lanez': 4,
#  'WizKid': 4,
#  'Maleek Berry': 5,
#  'Christopher Martin': 5,
#  'Kojo Funds': 5,
#  'Lil Uzi Vert': 4,
#  'Khary': 4,
#  'Rae Sremmurd': 4,
#  'DJ Esco': 4,
#  '21 Savage': 4,
#  'Travis Scott': 4,
#  'A$AP Rocky': 4,
#  'MadeinTYO': 4,
#  'Lil Yachty': 4,
#  'French Montana': 4,
#  'Chance The Rapper': 4,
#  'ScHoolboy Q': 4,
#  'Bankroll Fresh': 4,
#  'Gucci Mane': 4,
#  'Young Thug': 4,
#  'A$AP Mob': 4,
#  'Kendrick Lamar': 4,
#  'J. Cole': 4,
#  'Chief Keef': 4,
#  'Big Sean': 4,
#  'Kodak Black': 4,
#  'glue70': 4,
#  'Loso Loaded': 4,
#  'Ugly God': 4,
#  'Famous Dex': 4,
#  'KYLE': 4,
#  'ILoveMakonnen': 4,
#  'Migos': 4,
#  'Rick Ross': 4,
#  'Cellus Hale': 4,
#  'Jay Sean': 4,
#  'Chris Brown': 4,
#  'Iyaz': 4,
#  'T.I.': 4,
#  'Bassnectar': 4,
#  'Calvin Harris': 4,
#  'Alesso': 4,
#  'Gareth Emery': 4,
#  'Avicii': 4,
#  'Wyclef Jean': 4,
#  'Don Omar': 4,
#  'Tiësto': 4,
#  'Afrojack': 4,
#  'Fall Out Boy': 4,
#  'The Game': 4,
#  'Tove Lo': 4,
#  'Deorro': 4,
#  'David Guetta': 4,
#  'Showtek': 4,
#  'Sultan': 4,
#  'Tim Berg': 4,
#  'Swedish House Mafia': 4,
#  'Swanky Tunes': 4,
#  'Sebastian Ingrosso': 4,
#  'OneRepublic': 4,
#  'Diplo': 4,
#  'Skrillex': 4,
#  'Flosstradamus': 4,
#  'Martin Solveig': 4,
#  'Kaskade': 4,
#  'deadmau5': 4,
#  'Kygo': 4,
#  'Armin van Buuren': 4,
#  'Benny Benassi': 4,
#  '3LAU': 4,
#  'Keys N Krates': 4,
#  'RavenKis': 4,
#  'Adventure Club': 4,
#  'Dirty South': 4,
#  'Empire of the Sun': 4,
#  'Seinabo Sey': 4,
#  'CAZZETTE': 4,
#  'ODESZA': 4,
#  'Arty': 4,
#  'Vicetone': 4,
#  'Disclosure': 4,
#  'Lil Jon': 4,
#  'Fetty Wap': 4,
#  'Kap Slap': 4,
#  'Chedda Da Connect': 4,
#  'Wisin': 4,
#  'AronChupa': 4,
#  'Alvaro': 4,
#  'DJ Mustard': 4,
#  'Steve Aoki': 4,
#  'Tove Styrke': 4,
#  'Wiz Khalifa': 4,
#  'Cascada': 4,
#  'Ummet Ozcan': 4,
#  'Wes Walker': 4,
#  'CHVRCHES': 4,
#  'N.W.A.': 4,
#  'Audien': 4,
#  'Glass Animals': 4,
#  'Sir Sly': 4,
#  'Cage The Elephant': 4,
#  'Coconut Records': 4,
#  'Flume': 4,
#  'Khalid': 4,
#  'Norah Jones': 4,
#  'Mumford & Sons': 4,
#  'Blind Pilot': 4,
#  'alt-J': 4,
#  'Louis The Child': 4,
#  'Nohidea': 4,
#  'Kevin Gates': 4,
#  'One Direction': 4,
#  'Shawn Mendes': 4,
#  'DNCE': 4,
#  'Daya': 4,
#  'Ellie Goulding': 4,
#  'Bryson Tiller': 4,
#  'G-Eazy': 4,
#  'MisterWives': 4,
#  'ZAYN': 4,
#  'Charlie Puth': 4,
#  'Robin Schulz': 4,
#  'Kehlani': 4,
#  'Desiigner': 4,
#  'Mr_hotspot': 4,
#  'Black Coast': 4,
#  'Seizo': 4,
#  'The Arcs': 4,
#  'Matt Simons': 4,
#  'Justin Timberlake': 4,
#  'Lukas Graham': 4,
#  'Zara Larsson': 4,
#  'Kiiara': 4,
#  'Jonas Blue': 4,
#  'Thirdstory': 4,
#  'Nick Jonas': 4,
#  'gnash': 4,
#  'Alex Newell': 4,
#  'Karen Harding': 4,
#  'Deep Purple': 5,
#  'ZZ Top': 5,
#  'The Allman Brothers Band': 5,
#  'Van Morrison': 5,
#  'Steve Earle': 5,
#  'Warrant': 5,
#  'George Thorogood & The Destroyers': 5,
#  'Ram Jam': 5,
#  'Stone Temple Pilots': 5,
#  'Metallica': 5,
#  'Ozzy Osbourne': 5,
#  'Foreigner': 5,
#  'Jimi Hendrix': 5,
#  'Steve Miller Band': 5,
#  'Sublime': 5,
#  'Don McLean': 5,
#  'Van Halen': 5,
#  'Eric Church': 5,
#  'Hank Williams, Jr.': 5,
#  'David Allan Coe': 5,
#  'The Presidents Of The United States Of America': 5,
#  'Nickelback': 5,
#  'Grateful Dead': 5,
#  'Sheryl Crow': 5,
#  'Bachman-Turner Overdrive': 5,
#  'Bad Company': 5,
#  'The Cars': 5,
#  'Blue Öyster Cult': 5,
#  'Steppenwolf': 5,
#  'The Guess Who': 5,
#  'Alabama': 5,
#  'The Outlaws': 5,
#  'Merle Haggard': 5,
#  'Foghat': 5,
#  'Waylon Jennings': 5,
#  'Mel McDaniel': 5,
#  'The Marshall Tucker Band': 5,
#  'Boston': 5,
#  'Neil Young': 5,
#  'Tom Petty and the Heartbreakers': 5,
#  'Styx': 5,
#  'The Hollies': 5,
#  'Tom Petty': 5,
#  'Alice Cooper': 5,
#  'John Mellencamp': 5,
#  'Judas Priest': 5,
#  'Poison': 5,
#  'Golden Earring': 5,
#  'Rush': 5,
#  'The Who': 5,
#  'Bruce Springsteen': 5,
#  'Ted Nugent': 5,
#  'White Zombie': 5,
#  'Pantera': 5,
#  'Meek Mill': 4,
#  'Chinx': 4,
#  'Bobby Shmurda': 4,
#  'IshDARR': 4,
#  'Future': 4,
#  'Shy Glizzy': 4,
#  'Fabolous': 4,
#  'Young Buck': 4,
#  'Ludacris': 4,
#  'U.S.D.A.': 4,
#  'Boyz N Da Hood': 4,
#  'Jeezy': 4,
#  'Juelz Santana': 4,
#  'Wasiu': 4,
#  'Yo Gotti': 4,
#  'The Notorious B.I.G.': 4,
#  'D12': 4,
#  'P$C': 4,
#  'Trick Daddy': 4,
#  'Jim Jones': 4,
#  'Dr. Dre': 4,
#  'Vince Staples': 4,
#  'Snootie Wild': 4,
#  'Bun B': 4,
#  'Lloyd Banks': 4,
#  'Beanie Sigel': 4,
#  'Odd Future': 4,
#  'Obie Trice': 4,
#  'G-Unit': 4,
#  'Trillville': 4,
#  'Crime Mob': 4,
#  'DMX': 4,
#  'YG': 4,
#  'Westside Connection': 4,
#  'Uncle Murda': 4,
#  'Esco Racks': 4,
#  'Tee Grizzley': 4,
#  'Al Qaeda Jada': 4,
#  'Ab-Soul': 4,
#  'Phresher': 4,
#  'Lil Ronny Motha F': 4,
#  'Mike WiLL Made-It': 4,
#  'T-Wayne': 4,
#  'Youngbloodz': 4,
#  'Gorilla Zoe': 4,
#  'Ice Cube': 4,
#  'David Banner': 4,
#  'XXXTENTACION': 4,
#  'Ski Mask The Slump God': 4,
#  'Robin Thicke': 4,
#  'Ying Yang Twins': 4,
#  'Petey Pablo': 4,
#  'Cardi B': 4,
#  'A$AP Ferg': 4,
#  'The Real Tune': 4,
#  'The Weeknd': 4,
#  'Galantis': 4,
#  'Nicky Jam': 4,
#  'Felix Jaehn': 4,
#  'OMI': 4,
#  'Once Jameson': 4,
#  'Sigala': 4,
#  'Marcus Marr': 4,
#  'St. Lucia': 4,
#  'William Singe': 4,
#  'Miguel': 4,
#  'Rittz': 4,
#  'Kenny Chesney': 4,
#  'Ginuwine': 4,
#  'Thomas Rhett': 4,
#  'Trey Songz': 4,
#  'Jeremih': 4,
#  'Natalie La Rose': 4,
#  'xxyyxx': 5,
#  'The xx': 5,
#  'PARTYNEXTDOOR': 4,
#  'The Internet': 5,
#  'PnB Rock': 4,
#  'dvsn': 5,
#  'Kali Uchis': 5,
#  'Michael Franti & Spearhead': 4,
#  'will.i.am': 4,
#  'Moby': 4,
#  'Kelly Clarkson': 4,
#  'Neon Trees': 4,
#  'Rick James': 4,
#  'Cake': 4,
#  'P!nk': 4,
#  'LL Cool J': 4,
#  'Mase': 4,
#  'David Barrett': 4,
#  'Starset': 5,
#  'Black Veil Brides': 5,
#  'Social Repose': 5,
#  'You Me At Six': 5,
#  'Otherwise': 5,
#  'Michael Jackson': 4,
#  'Rob Curly': 4,
#  'The Code': 4,
#  '6LACK': 4,
#  'Drake Chisholm': 4,
#  'Logic': 4,
#  'Roy Woods': 4,
#  'Alvaro Soler': 5,
#  'Diego Boneta': 5,
#  'Alex Aiono': 5,
#  'The Antlers': 5,
#  'Arcade Fire': 4,
#  'Mister Heavenly': 5,
#  'The Blow': 5,
#  'Wale': 4,
#  'Matoma': 4,
#  'Dru Hill': 4,
#  'Machine Gun Kelly': 4,
#  'R. City': 4,
#  'Katy Perry': 4,
#  'Kesha': 4,
#  'Elle King': 4,
#  'Silentó': 4,
#  'Rachel Platten': 4,
#  'X Ambassadors': 4,
#  'B.o.B': 4,
#  'Gwen Stefani': 4,
#  'Rixton': 4,
#  'Gym Class Heroes': 4,
#  'Carly Rae Jepsen': 4,
#  'Jess Glynne': 4,
#  'Tori Kelly': 4,
#  'The Script': 4,
#  'Iggy Azalea': 4,
#  'Bon Jovi': 4,
#  'Usher': 4,
#  'Taio Cruz': 4,
#  'Alexandra Stan': 4,
#  'Hardwell': 4,
#  'Shawn Hook': 4,
#  'Lady Gaga': 4,
#  'Willie Nelson': 6,
#  'Timeflies': 4,
#  'LFO': 4,
#  'Kris Kross': 4,
#  '99 Percent': 4,
#  'RAC': 4,
#  'The 1975': 4,
#  'Keith Urban': 4,
#  '*NSYNC': 4,
#  '5 Seconds of Summer': 4,
#  'Yellowcard': 4,
#  'Hot Chelle Rae': 4,
#  'The Ready Set': 4,
#  'Hudson Thames': 4,
#  'House Of Pain': 4,
#  'Vanilla Ice': 4,
#  'Yeah Yeah Yeahs': 4,
#  'Mike Diva': 4,
#  'Vanessa Carlton': 4,
#  'Ella Eyre': 4,
#  'MNEK': 4,
#  'Olly Murs': 4,
#  'James Blake': 4,
#  'Santigold': 4,
#  'Klingande': 4,
#  'The Knocks': 4,
#  'Gallant': 4,
#  'Ashley DuBose': 4,
#  'Purity Ring': 4,
#  'Banks': 4,
#  'Broods': 4,
#  'Daft Punk': 4,
#  'Grace Pitts': 4,
#  'R E L': 4,
#  'Recable': 4,
#  'Tourist': 4,
#  'Catching Flies': 4,
#  'C418': 4,
#  'Shiny Toy Guns': 4,
#  'The Chain Gang Of 1974': 4,
#  'ZHU': 4,
#  'Savoir Adore': 4,
#  'Singularity': 4,
#  'Andrew Belle': 4,
#  'Hippie Sabotage': 4,
#  'Example': 4,
#  'Late Night Alumni': 4,
#  'Mark Norman': 4,
#  'Clams Casino': 4,
#  'Ryan Dolan': 4,
#  'Meg Myers': 4,
#  'Alice Kristiansen': 4,
#  'Hundred Waters': 4,
#  'Grimes': 4,
#  'Frou Frou': 4,
#  'Pr0files': 4,
#  'Night Riots': 4,
#  'Groove Armada': 4,
#  'Lewis Del Mar': 4,
#  'Tycho': 4,
#  'Avril Lavigne': 4,
#  'Seanloui': 4,
#  'Dhruva Aliman': 4,
#  'James Horner': 4,
#  'MOVEMENT': 4,
#  'Shy Girls': 4,
#  'SOHN': 4,
#  'Rosie Lowe': 4,
#  'Phantogram': 4,
#  'Thomas Newman': 4,
#  'Halloween Masters': 4,
#  'Washed Out': 4,
#  'Rich Edwards': 4,
#  'Tep No': 4,
#  'Lucas Nord': 4,
#  'Dan Aux': 4,
#  'Gemini Club': 4,
#  'The Felix': 4,
#  'Skies Speak': 4,
#  'Angel Olsen': 4,
#  'Highasakite': 4,
#  'Vanic': 4,
#  'Jai Wolf': 4,
#  'Seven Lions': 4,
#  'Chrome Sparks': 4,
#  'The Griswolds': 4,
#  'Gryffin': 4,
#  'Big Wild': 4,
#  'Slushii': 4,
#  'Mr Little Jeans': 4,
#  'Tash Sultana': 4,
#  'Frank Ocean': 4,
#  'Omarion': 4,
#  'Rich Homie Quan': 4,
#  'House Party': 4,
#  'Jamie Foxx': 4,
#  'Rocko': 4,
#  'Ty Dolla $ign': 4,
#  'Rich Chigga': 4,
#  'Pouya': 4,
#  'Aminé': 4,
#  'Young Money': 4,
#  'Nipsey Hussle': 4,
#  'Waka Flocka Flame': 4,
#  'Romeo Santos': 4,
#  'Snoop Lion': 4,
#  'Mary J. Blige': 4,
#  'DJ Drama': 4,
#  ...}

# %%
nx.diameter(graph)
# Out:
# 4

# %%
nx.periphery(graph)
# Out:
# ['Lynyrd Skynyrd',
#  'Bad Company',
#  'Styx',
#  'Eagles',
#  'Queen',
#  'Buffalo Springfield',
#  'The Who',
#  'Tom Petty',
#  'The Rolling Stones',
#  'George Thorogood & The Destroyers',
#  'Billy Joel',
#  'Foreigner',
#  'Jeff Gutt',
#  'The Hit Co.',
#  'Carl Wave',
#  'Purity Ring',
#  'ODESZA',
#  'Banks',
#  'Broods',
#  'Daft Punk',
#  'Grace Pitts',
#  'Alina Baraz',
#  'R E L',
#  'Recable',
#  'Tourist',
#  'Catching Flies',
#  'C418',
#  'Shiny Toy Guns',
#  'The Chain Gang Of 1974',
#  'ZHU',
#  'Savoir Adore',
#  'Singularity',
#  'Andrew Belle',
#  'Hippie Sabotage',
#  'Example',
#  'Late Night Alumni',
#  'Mark Norman',
#  'Clams Casino',
#  'Ryan Dolan',
#  'Meg Myers',
#  'Alice Kristiansen',
#  'Hundred Waters',
#  'Grimes',
#  'Frou Frou',
#  'Pr0files',
#  'Night Riots',
#  'Groove Armada',
#  'Lewis Del Mar',
#  'Tycho',
#  'Avril Lavigne',
#  'Seanloui',
#  'Florence + The Machine',
#  'Dhruva Aliman',
#  'James Horner',
#  'Yeah Yeah Yeahs',
#  'MOVEMENT',
#  'Shy Girls',
#  'SOHN',
#  'Rosie Lowe',
#  'Phantogram',
#  'Thomas Newman',
#  'Halloween Masters',
#  'Washed Out',
#  'Rich Edwards',
#  'Tep No',
#  'Lucas Nord',
#  'Dan Aux',
#  'Gemini Club',
#  'The Felix',
#  'Skies Speak',
#  'Angel Olsen',
#  'Highasakite',
#  'Vanic',
#  'Jai Wolf',
#  'Seven Lions',
#  'Chrome Sparks',
#  'Gryffin',
#  'Big Wild',
#  'Slushii',
#  'Mr Little Jeans',
#  'Tash Sultana',
#  'Jay Sean',
#  'Iyaz',
#  'Bear Hands',
#  'Bleachers',
#  'Atlas Genius',
#  'Sleeper Agent',
#  'Benjamin Francis Leftwich',
#  'Grouplove',
#  'Modest Mouse',
#  'Big Data',
#  'American Authors',
#  'Two Door Cinema Club',
#  'Family of the Year',
#  'Cage The Elephant',
#  'Sir Sly',
#  'Milky Chance',
#  'Capital Cities',
#  'alt-J',
#  'Hozier',
#  'Phoenix',
#  'Vance Joy',
#  'Wild Cub',
#  'The 1975',
#  'The Naked And Famous',
#  'Foster The People',
#  'Arcade Fire',
#  'Passion Pit',
#  'Arctic Monkeys',
#  'Of Monsters and Men',
#  'The Head and the Heart',
#  'The Paper Kites',
#  'Hammock',
#  'Ólafur Arnalds',
#  'Helios',
#  'NazcarNation',
#  'Thievery Corporation',
#  'José González',
#  'Edward Sharpe & The Magnetic Zeros',
#  'Parra for Cuva',
#  'Mr. Probz',
#  'Sam Smith',
#  'Duke Dumont',
#  'RJD2',
#  'Rudimental',
#  'Amber Run',
#  'Daithí',
#  'Mapei',
#  'Flight Facilities',
#  'Daughter',
#  'Dr. Toast',
#  'Jonathan Byrd',
#  'Evenings',
#  'The Antlers',
#  'Mister Heavenly',
#  'The Blow',
#  'Alvaro Soler',
#  'Diego Boneta',
#  'Alex Aiono']

# %%
nx.radius(graph)
# Out:
# 2

# %%
nx.center(graph)
# Out:
# ['Adele',
#  'Lorde',
#  'Lil Wayne',
#  'Tim McGraw',
#  'AWOLNATION',
#  'Ed Sheeran',
#  'Luke Bryan']

# %% [markdown]
# ### Degree, Closeness, Betweenness and Eigenvector Centrality

# %%
# the degree of network(g)
fig, ax = plt.subplots(1,1,figsize=(15,12))
pos = nx.spring_layout(graph,seed=123456789,k=0.5)
degree_dict = dict(nx.degree(graph))
color = list(degree_dict.values())
nx.draw_networkx_edges(graph,
                       pos=pos,
                       alpha=0.4, ax=ax)
nodes = nx.draw_networkx_nodes(graph,
                 pos=pos,
                 node_color=color,
                 cmap=plt.cm.jet,ax=ax)
nx.draw_networkx_labels(graph, pos=pos,
                        font_color='white', ax=ax)


plt.axis("off")
plt.colorbar(nodes)
plt.savefig('degree.png', transparent=True,dpi=300)
plt.show()

# %%
print("Top 10 nodes per degree ")
sorted(list(degree_dict.items()),key=lambda x:x[1],reverse=True)[:10]
# Out:
# Top 10 nodes per degree
# [('The Chainsmokers', 199),
#  ('Snakehips', 199),
#  ('Lil Wayne', 159),
#  ('Alessia Cara', 151),
#  ('Adele', 150),
#  ('Drake', 135),
#  ('Mike Posner', 131),
#  ('Meghan Trainor', 131),
#  ('Luis Fonsi', 127),
#  ('Post Malone', 125)]

# %%
# the closeness centrality 
fig, ax = plt.subplots(1,1,figsize=(15,12))
pos = nx.spring_layout(graph,seed=123456789,k=0.5)
closeness_dict = dict(nx.closeness_centrality(graph))
color = list(closeness_dict.values())
nx.draw_networkx_edges(graph,
                       pos=pos,
                       alpha=0.4, ax=ax)
nodes = nx.draw_networkx_nodes(graph,
                 pos=pos,
                 node_color=color,
                 cmap=plt.cm.jet,
                 ax=ax)
nx.draw_networkx_labels(graph, pos=pos,
                        font_color='white', ax=ax)

plt.axis("off")
plt.colorbar(nodes)
plt.savefig('closeness_centrality.png', transparent=True,dpi=300)
plt.show()

# %%
print("Top 10 nodes per closeness centrality ")
sorted(list(closeness_dict.items()),key=lambda x:x[1],reverse=True)[:10]
# Out:
# Top 10 nodes per closeness centrality
# [('The Chainsmokers', 0.64),
#  ('Snakehips', 0.64),
#  ('Lil Wayne', 0.6181277860326895),
#  ('Adele', 0.6099706744868035),
#  ('Alessia Cara', 0.5959885386819485),
#  ('Luis Fonsi', 0.5884016973125884),
#  ('Twenty One Pilots', 0.5867418899858956),
#  ('Foo Fighters', 0.5859154929577465),
#  ('Drake', 0.5818181818181818),
#  ('Mike Posner', 0.5793871866295265)]

# %%
# the betwenness centrality 
fig, ax = plt.subplots(1,1,figsize=(15,12))
pos = nx.spring_layout(graph,seed=123456789,k=0.5)
betweenness_dict = dict(nx.betweenness_centrality(graph))
color = list(betweenness_dict.values())
nx.draw_networkx_edges(graph,
                       pos=pos,
                       alpha=0.4, ax=ax)
nodes = nx.draw_networkx_nodes(graph,
                 pos=pos,
                 node_color=color,
                 cmap=plt.cm.jet,
                 ax=ax)
nx.draw_networkx_labels(graph, pos=pos,
                        font_color='white', ax=ax)
plt.axis("off")
plt.colorbar(nodes)
plt.savefig('betweenness_centrality.png', transparent=True,dpi=300)
plt.show()

# %%
print("Top 10 nodes per betwenness centrality ")
sorted(list(betweenness_dict.items()),key=lambda x:x[1],reverse=True)[:10]
# Out:
# Top 10 nodes per betwenness centrality
# [('Twenty One Pilots', 0.07580123266558665),
#  ('The Chainsmokers', 0.07419938684931444),
#  ('Snakehips', 0.07419938684931444),
#  ('Lil Wayne', 0.06699225847786745),
#  ('Clean Bandit', 0.05104473482572417),
#  ('French Montana', 0.045601276897854266),
#  ('Sia', 0.04500875206042029),
#  ('DJ Khaled', 0.043711277123558635),
#  ('Luis Fonsi', 0.039023210922770606),
#  ('Eminem', 0.03792889243745329)]

# %%
# the eigenvector centrality 
fig, ax = plt.subplots(1,1,figsize=(15,12))
pos = nx.spring_layout(graph,seed=123456789,k=0.5)
eigenvector_dict = dict(nx.eigenvector_centrality(graph))
color = list(eigenvector_dict.values())
nx.draw_networkx_edges(graph,
                       pos=pos,
                       alpha=0.4, ax=ax)
nodes = nx.draw_networkx_nodes(graph,
                 pos=pos,
                 node_color=color,
                 cmap=plt.cm.jet,
                 ax=ax)
nx.draw_networkx_labels(graph, pos=pos,
                        font_color='white', ax=ax)

plt.axis("off")
plt.colorbar(nodes)
plt.savefig('eigenvector_centrality.png', transparent=True,dpi=300)
plt.show()

# %%
print("Top 10 nodes per eigenvector centrality ")
sorted(list(eigenvector_dict.items()),key=lambda x:x[1],reverse=True)[:10]
# Out:
# Top 10 nodes per eigenvector centrality
# [('The Chainsmokers', 0.13206748062127746),
#  ('Snakehips', 0.13206748062127746),
#  ('Adele', 0.11831272367089857),
#  ('Alessia Cara', 0.11775483619450669),
#  ('Mike Posner', 0.11555979023858493),
#  ('Meghan Trainor', 0.11555979023858493),
#  ('Lil Wayne', 0.11161654624220496),
#  ('Post Malone', 0.1083379232657719),
#  ('Luis Fonsi', 0.10641480713707265),
#  ('Foo Fighters', 0.10637076117653123)]

# %% [markdown]
# ## Bivariate Analysis

# %%
plt.style.use("fivethirtyeight")
#plt.style.use("default")
degree_sequence = sorted([d for n, d in graph.degree()], reverse=True)  
fig, ax = plt.subplots(1,1,figsize=(10,8))

sns.histplot(degree_sequence,bins=7,label="Count",ax=ax)
ax2 = ax.twinx()
sns.kdeplot(degree_sequence,color='r',label="Probability Density Function (PDF)",ax=ax2)

# ask matplotlib for the plotted objects and their labels
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0)

ax.grid(False)
ax2.grid(False)
ax.set_xlabel("Degree")
ax2.set_ylabel("Probability")

plt.savefig('probability_density_function.png', transparent=True,dpi=600,bbox_inches="tight")
plt.show()

# %%
plt.style.use("fivethirtyeight")
#plt.style.use("default")

fig, ax = plt.subplots(1,1,figsize=(10,8))

sns.histplot(degree_sequence,bins=7,label="Count",ax=ax)
ax2 = ax.twinx()
sns.kdeplot(degree_sequence,color='r',label="Cumulative Density Function (CDF)",ax=ax2,cumulative=True)

# ask matplotlib for the plotted objects and their labels
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0)

ax.grid(False)
ax2.grid(False)
ax.set_xlabel("Degree")
ax2.set_ylabel("Probability")

plt.savefig('cumulative_density_function.png', transparent=True,dpi=600,bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Multivariate analysis

# %%
bc = pd.Series(nx.betweenness_centrality(graph))
dc = pd.Series(nx.degree_centrality(graph))
ec = pd.Series(nx.eigenvector_centrality(graph))
cc = pd.Series(nx.closeness_centrality(graph))

df = pd.DataFrame.from_dict({"Betweenness": bc,
                            "Degree": dc,
                            "EigenVector": ec,
                            "Closeness": cc})
df.reset_index(inplace=True,drop=True)
df.head()
# Out:
#    Betweenness    Degree  EigenVector  Closeness
# 0     0.022967  0.281250     0.105165   0.568306
# 1     0.074199  0.478365     0.132067   0.640000
# 2     0.000000  0.201923     0.102550   0.543791
# 3     0.016384  0.300481     0.108338   0.574586
# 4     0.000000  0.201923     0.102550   0.543791

# %%
fig = sns.PairGrid(df)
fig.map_upper(sns.scatterplot)
fig.map_lower(sns.kdeplot, cmap="Reds_r")
fig.map_diag(sns.kdeplot, lw=2, legend=False)

plt.savefig('all.png', transparent=True,dpi=800,bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Network Decomposition Analysis

# %%
set([v for k,v in nx.core_number(graph).items()])
# Out:
# {3, 4, 5, 15, 16, 20, 22, 25, 26, 34, 41, 47, 52, 72, 84}

# %%
# the degree of network
fig, ax = plt.subplots(1,1,figsize=(10,8))

# Find k-cores
graph_core_72 = nx.k_shell(graph, 72)
graph_core_84 = nx.k_core(graph, 84)

# layout position
pos = nx.spring_layout(graph,seed=123456789,k=0.3)

# draw edges
nx.draw_networkx_edges(graph,
                       pos=pos,
                       alpha=0.4, ax=ax)

# draw nodes
nodes = nx.draw_networkx_nodes(graph,
                 pos=pos,
                 node_color="#333333")

# draw nodes
nodes = nx.draw_networkx_nodes(graph_core_72,
                 pos=pos,
                 node_color="blue")

nodes = nx.draw_networkx_nodes(graph_core_84,
                 pos=pos,
                 node_color="red")

# static legend
red_patch = mpatches.Patch(color='red', label='84-core')
blue_patch = mpatches.Patch(color='blue', label='72-shell')
plt.legend(handles=[red_patch,blue_patch])

plt.axis("off")
plt.savefig('k-core_sociopatterns.png', transparent=True,dpi=600)
plt.show()
